# %% [markdown]
# # Week 1 Homework - Intro

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Question 1
# What's the version of Pandas that you installed?

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Out:
# --2023-09-26 23:15:45--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8000::154, 2606:50c0:8001::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8000::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: 'housing.csv'
#
#      0K .......... .......... .......... .......... ..........  3% 1.07M 1s
#     50K .......... .......... .......... .......... ..........  7% 10.3M 1s
#    100K .......... .......... .......... .......... .......... 10% 2.73M 1s
#    150K .......... .......... .......... .......... .......... 14% 7.31M 0s
#    200K .......... .......... .......... .......... .......... 17% 7.58M 0s
#    250K .......... .......... .......... .......... .......... 21% 5.00M 0s
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv')

# %% [markdown]
# # Question 2
# How many columns are in the dataset?

# %%
print(f'Number of rows:{df.shape[0]}\tNumber of columns:{df.shape[1]}')
# Out:
# Number of rows:20640	Number of columns:10

# %% [markdown]
# # Question 3
# Which columns in the dataset have missing values?

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# Column `total_bedrooms` has missing values.

# %% [markdown]
# # Question 4
# How many unique values does the `'ocean_proximity'` column have?

# %%
df['ocean_proximity'].nunique()
# Out:
# 5

# %%
df['ocean_proximity'].value_counts().index.values
# Out:
# array(['<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'NEAR BAY', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# # Question 5
# What's the average value of the `'median_house_value'` for the houses located near the bay?

# %%
df.groupby(by='ocean_proximity')['median_house_value'].mean()['NEAR BAY']
# Out:
# 259212.31179039303

# %% [markdown]
# # Question 6

# %%
mean_total_bedroom = df["total_bedrooms"].mean()
print(f'Mean of total bedrooms with missing values: {mean_total_bedroom:.3f}')
imputed_mean_total_bedroom = df["total_bedrooms"].fillna(mean_total_bedroom).mean()
print(f'Mean of total bedrooms with mean as imputation: {imputed_mean_total_bedroom:.3f}')
# Out:
# Mean of total bedrooms with missing values: 537.871
# Mean of total bedrooms with mean as imputation: 537.871

# %% [markdown]
# Considering 3 decimals only, there is no change.

# %% [markdown]
# # Question 7

# %%
island_df = df[df.ocean_proximity == 'ISLAND']
island_df = island_df[['housing_median_age', 'total_rooms', 'total_bedrooms']]
island_df
# Out:
#       housing_median_age  total_rooms  total_bedrooms
# 8314                27.0       1675.0           521.0
# 8315                52.0       2359.0           591.0
# 8316                52.0       2127.0           512.0
# 8317                52.0        996.0           264.0
# 8318                29.0        716.0           214.0

# %%
X = island_df.values
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)
y = [950, 1300, 800, 1000, 1300]
w = (XTX_inv @ X.T) @ y
w[-1] # last value of weight vector
# Out:
# 5.699229455065586
